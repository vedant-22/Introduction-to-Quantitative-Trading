# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import yfinance as yf

def stock(str1):
    inp1 = yf.download(str1 , start="2022-01-01", end="2023-01-01")['Open']
    inp2 = yf.download(str1, start="2022-01-01", end="2023-01-01")['Close']
    inp3 = yf.download(str1, start="2022-01-01", end="2023-01-01")['High']
    inp4 = yf.download(str1, start="2022-01-01", end="2023-01-01")['Low']
    
    oc = inp1/inp2
    ol = inp1/inp4
    hl = inp3/inp4
    hc = inp3/inp2
    
    a=b=c=d=a1=a2=a3=b1=b2=b3=c1=c2=c3=d1=d2=d3=0
    
    if(oc.iloc[0] == 0.35):
        a=a+1

    if(oc.iloc[0] == 0.5):
        b=b+1

    if(oc.iloc[0] == 1):
        c=c+1

    if(oc.iloc[0] == 3.5):
        d=d+1

    if(ol.iloc[0] == 0.35):
        a1=a1+1

    if(ol.iloc[0] == 0.5):
        b1=b1+1

    if(ol.iloc[0] == 1):
        c1=c1+1

    if(ol.iloc[0] == 3.5):
        d1=d1+1 
        
    if(hl.iloc[0] == 0.35):
        a2=a2+1

    if(hl.iloc[0] == 0.5):
        b2=b2+1

    if(hl.iloc[0] == 1):
        c2=c2+1

    if(hl.iloc[0] == 3.5):
        d2=d2+1

    if(hc.iloc[0] == 0.35):
        a3=a3+1

    if(hc.iloc[0] == 0.5):
        b3=b3+1

    if(hc.iloc[0] == 1):
        c3=c3+1

    if(hc.iloc[0] == 3.5):
        d3=d3+1  
        
        
    print("The no. of times Open/Close ratio becomes equal to 0.35, 0.5, 1, 3.5 respetively is:", a, b, c, d)
    print("The no. of times Open/Low ratio becomes equal to 0.35, 0.5, 1, 3.5 respetively is:", a1, b1, c1, d1)
    print("The no. of times High/Low ratio becomes equal to 0.35, 0.5, 1, 3.5 respetively is:", a2, b2, c2, d2)
    print("The no. of times High/Close ratio becomes equal to 0.35, 0.5, 1, 3.5 respetively is:", a3, b3, c3, d3)
    

stock('AAPL')
stock('AMZN')
stock('GOOGL')
stock('MSFT')
stock('TSLA')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The no. of times Open/Close ratio becomes equal to 0.35, 0.5, 1, 3.5 respetively is: 0 0 0 0
# The no. of times Open/Low ratio becomes equal to 0.35, 0.5, 1, 3.5 respetively is: 0 0 0 0
# The no. of times High/Low ratio becomes equal to 0.35, 0.5, 1, 3.5 respetively is: 0 0 0 0
# The no. of times High/Close ratio becomes equal to 0.35, 0.5, 1, 3.5 respetively is: 0 0 0 0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
import mplfinance as mf
import yfinance as yf
appl = yf.download('AAPL', start="2020-01-01", end="2023-01-01")
mf.plot(
    appl,
            type='candle',
            style='binance',
            figratio = (15,7),
            title='Apple',
            ylabel='Price($)',
)
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\viraa\AppData\Local\Programs\Python\Python310\lib\site-packages\mplfinance\_arg_validators.py:83: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

tickers_list = ['AAPL', 'AMZN']

data = yf.download(tickers_list, start="2022-01-01", end="2023-01-01")['Close']
# Plot all the close prices
plt.figure(figsize=(10,6))
data.plot()

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Closing Price vs Year for AAPL and AMZN", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Closing Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed
